# %% [markdown]
# # Evaluate trained models on a task and check success rate

# %% [markdown]
# Load the necessary library

# %%
import numpy as np
import torch
import hydra
from omegaconf import DictConfig
import datetime
from omniisaacgymenvs.utils.hydra_cfg.hydra_utils import *
from omniisaacgymenvs.utils.hydra_cfg.reformat import omegaconf_to_dict, print_dict
from rl_games.algos_torch.players import PpoPlayerDiscrete
from rl_games.algos_torch.players import BasicPpoPlayerContinuous, BasicPpoPlayerDiscrete

from omniisaacgymenvs.utils.rlgames.rlgames_utils import RLGPUAlgoObserver, RLGPUEnv

from omniisaacgymenvs.scripts.rlgames_train import RLGTrainer
from rl_games.torch_runner import Runner
from omniisaacgymenvs.utils.task_util import initialize_task
from omniisaacgymenvs.envs.vec_env_rlgames import VecEnvRLGames
from omniisaacgymenvs.utils.config_utils.path_utils import retrieve_checkpoint_path
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator
from torch._C import fork
from gym import spaces
import numpy as np
import torch
import yaml


from plot_experiment import plot_episode_data_virtual
from eval_metrics import success_rate_from_distances
# Out:
# [Warning] [omni.isaac.kit] Interactive python shell detected but ISAAC_JUPYTER_KERNEL was not set. Problems with asyncio may occur

# %%
def eval_multi_agents(cfg):

    base_dir = "./evaluations/"
    experiment_name = cfg.checkpoint.split("/")[1]
    print(f'Experiment name: {experiment_name}')
    evaluation_dir = base_dir + experiment_name + "/"
    os.makedirs(evaluation_dir, exist_ok=True)

    rlg_config_dict = omegaconf_to_dict(cfg.train)
    print(rlg_config_dict)
    runner = Runner(RLGPUAlgoObserver())
    runner.load(rlg_config_dict)
    runner.reset()

    agent = runner.create_player()
    agent.restore(cfg.checkpoint)

    store_all_agents = True # store all agents generated data, if false only the first agent is stored
    is_done = False
    env = agent.env
    obs = env.reset()

    ep_data = {'act': [], 'obs': [], 'rews': [], 'info': [], 'all_dist': []}
    total_reward = 0
    num_steps = 0
    
    total_num_steps = 800
    for _ in range(total_num_steps):
        actions = agent.get_action(obs['obs'], is_deterministic=True)
        obs, reward, done, info = env.step(actions)
        
        #print(f'Step {num_steps}: obs={obs["obs"]}, rews={reward}, dones={done}, info={info} \n')
        if store_all_agents:
            ep_data['act'].append(actions.cpu().numpy())
            ep_data['obs'].append(obs['obs']['state'].cpu().numpy())
            ep_data['rews'].append(reward.cpu().numpy())  
        else:
            ep_data['act'].append(actions[0].cpu().numpy())
            ep_data['obs'].append(obs['obs']['state'][0].cpu().numpy())
            ep_data['rews'].append(reward[0].cpu().numpy())
        #ep_data['info'].append(info)
        x_pos = obs['obs']['state'][:,6].cpu().numpy()
        y_pos = obs['obs']['state'][:,7].cpu().numpy()
        ep_data['all_dist'].append(np.linalg.norm(np.array([x_pos, y_pos]), axis=0))
        total_reward += reward[0]
        num_steps += 1
        is_done = done.any()
    ep_data['obs'] = np.array(ep_data['obs'])
    ep_data['act'] = np.array(ep_data['act'])
    ep_data['rews'] = np.array(ep_data['rews'])
    ep_data['all_dist'] = np.array(ep_data['all_dist'])

    print(f'\n Episode: rew_sum={total_reward:.2f}, tot_steps={num_steps} \n')
    #print(f'Episode data: {ep_data} \n')
    print(f'Episode data obs shape: {ep_data["obs"].shape} \n')

    #if not cfg.headless:
    #plot_episode_data_virtual(ep_data, evaluation_dir, store_all_agents)
    success_rate = success_rate_from_distances(ep_data['all_dist'])
    print(success_rate)

# %%
   
@hydra.main(config_name="config", config_path="../cfg")
def parse_hydra_configs(cfg: DictConfig):
    
    if cfg.checkpoint is None:
        print("No checkpoint specified. Exiting...")
        return

    # set congig params for evaluation
    cfg.task.env.maxEpisodeLength = 802
    cfg.task.env.clipObservations['state'] = 20.0
    cfg.task.env.task_parameters['max_spawn_dist'] = 5.0
    cfg.task.env.task_parameters['min_spawn_dist'] = 4.5  
    cfg.task.env.task_parameters['kill_dist'] = 6.0
    cfg.task.env.task_parameters['kill_after_n_steps_in_tolerance'] = 400
    # TODO: check error with visualizer of thrusters....  ANTOINE
    #cfg.task.env.platform.configuration.visualize = False
    cfg_dict = omegaconf_to_dict(cfg)
    print_dict(cfg_dict)

    # _____Create environment_____

    headless = cfg.headless
    enable_viewport = "enable_cameras" in cfg.task.sim and cfg.task.sim.enable_cameras

    env = VecEnvRLGames(headless=headless, sim_device=cfg.device_id, enable_livestream=cfg.enable_livestream, enable_viewport=enable_viewport)

    
    from omni.isaac.core.utils.torch.maths import set_seed
    cfg.seed = set_seed(cfg.seed, torch_deterministic=cfg.torch_deterministic)
    cfg.seed = cfg.seed + 6
    cfg_dict['seed'] = cfg.seed
    task = initialize_task(cfg_dict, env)

    # Activate wandb logging
    if cfg.wandb_activate:
        activate_wandb(cfg, cfg_dict, task)

    rlg_trainer = RLGTrainer(cfg, cfg_dict)
    rlg_trainer.launch_rlg_hydra(env)
    # _____Create players (model)_____
    
    #eval_single_agent(cfg_dict, cfg, env)
    eval_multi_agents(cfg)

    if cfg.wandb_activate:
        wandb.finish()
    env.close()

if __name__ == '__main__':
    parse_hydra_configs()
# Out:
# usage: ipykernel_launcher.py [--help] [--hydra-help] [--version]
#                              [--cfg {job,hydra,all}] [--resolve]
#                              [--package PACKAGE] [--run] [--multirun]
#                              [--shell-completion] [--config-path CONFIG_PATH]
#                              [--config-name CONFIG_NAME]
#                              [--config-dir CONFIG_DIR]
#                              [--info [{all,config,defaults,defaults-tree,plugins,searchpath}]]
#                              [overrides [overrides ...]]
# ipykernel_launcher.py: error: argument --shell-completion/-sc: ignored explicit argument '9002'
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/matteo/.local/share/ov/pkg/isaac_sim-2022.2.1/kit/python/lib/python3.7/argparse.py", line 1787, in parse_known_args
#     namespace, args = self._parse_known_args(args, namespace)
#   File "/home/matteo/.local/share/ov/pkg/isaac_sim-2022.2.1/kit/python/lib/python3.7/argparse.py", line 1993, in _parse_known_args
#     start_index = consume_optional(start_index)
#   File "/home/matteo/.local/share/ov/pkg/isaac_sim-2022.2.1/kit/python/lib/python3.7/argparse.py", line 1915, in consume_optional
#     raise ArgumentError(action, msg % explicit_arg)
# argparse.ArgumentError: argument --shell-completion/-sc: ignored explicit argument '9002'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/matteo/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_16288/4219626332.py", line 50, in <module>
#     parse_hydra_configs()
#   File "/home/matteo/.local/share/ov/pkg/isaac_sim-2022.2.1/kit/python/lib/python3.7/site-packages/hydra/main.py", line 52, in decorated_main
#     config_name=config_name,
#   File "/home/matteo/.local/share/ov/pkg/isaac_sim-2022.2.1/kit/python/lib/python3.7/site-packages/hydra/_internal/utils.py", line 309, in _run_hydra
#     args = args_parser.parse_args()
#   File "/home/matteo/.local/share/ov/pkg/isaac_sim-2022.2.1/kit/python/lib/python3.7/argparse.py", line 1755, in parse_args
#     args, argv = self.parse_known_args(args, namespace)
#   File "/home/matteo/.local/share/ov/pkg/isaac_sim-2022.2.1/kit/python/lib/python3.7/argparse.py", line 1794, in parse_known_args
#     self.error(str(err))
#   File "/home/matteo/.local/share/ov/pkg/isaac_sim-2022.2.1/kit/python/lib/python3.7/argparse.py", line 2508, in error
#     self.exit(2, _('%(prog)s: error: %(message)s\n') % args)
#   File "/home/matteo/.local/share/ov/pkg/isaac_sim-2022.2.1/kit/python/lib/python3.7/argparse.py", line 2495, in exit
#     _sys.exit(status)
# SystemExit: 2
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/matteo/.local/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/matteo/.local/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/matteo/.local/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/matteo/.local/share/ov/pkg/isaac_sim-2022.2.1/kit/python/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
# AttributeError: 'tuple' object has no attribute 'tb_frame'
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# ~/.local/share/ov/pkg/isaac_sim-2022.2.1/kit/python/lib/python3.7/argparse.py in parse_known_args(self, args, namespace)
#    1786         try:
# -> 1787             namespace, args = self._parse_known_args(args, namespace)
#    1788             if hasattr(namespace, _UNRECOGNIZED_ARGS_ATTR):
#
# ~/.local/share/ov/pkg/isaac_sim-2022.2.1/kit/python/lib/python3.7/argparse.py in _parse_known_args(self, arg_strings, namespace)
#    1992             # consume the next optional and any arguments for it
# -> 1993             start_index = consume_optional(start_index)
#    1994
#
# ~/.local/share/ov/pkg/isaac_sim-2022.2.1/kit/python/lib/python3.7/argparse.py in consume_optional(start_index)
#    1914                         msg = _('ignored explicit argument %r')
# -> 1915                         raise ArgumentError(action, msg % explicit_arg)
#    1916
#
# ArgumentError: argument --shell-completion/-sc: ignored explicit argument '9002'
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_16288/4219626332.py in <module>
#      49 if __name__ == '__main__':
# ---> 50     parse_hydra_configs()
#
# ~/.local/share/ov/pkg/isaac_sim-2022.2.1/kit/python/lib/python3.7/site-packages/hydra/main.py in decorated_main(cfg_passthrough)
#      51                     config_path=config_path,
# ---> 52                     config_name=config_name,
#      53                 )
#
# ~/.local/share/ov/pkg/isaac_sim-2022.2.1/kit/python/lib/python3.7/site-packages/hydra/_internal/utils.py in _run_hydra(args_parser, task_function, config_path, config_name)
#     308
# --> 309     args = args_parser.parse_args()
#     310     if args.config_name is not None:
#
# ~/.local/share/ov/pkg/isaac_sim-2022.2.1/kit/python/lib/python3.7/argparse.py in parse_args(self, args, namespace)
#    1754     def parse_args(self, args=None, namespace=None):
# -> 1755         args, argv = self.parse_known_args(args, namespace)
#    1756         if argv:
#
# ~/.local/share/ov/pkg/isaac_sim-2022.2.1/kit/python/lib/python3.7/argparse.py in parse_known_args(self, args, namespace)
#    1793             err = _sys.exc_info()[1]
# -> 1794             self.error(str(err))
#    1795
#
# ~/.local/share/ov/pkg/isaac_sim-2022.2.1/kit/python/lib/python3.7/argparse.py in error(self, message)
#    2507         args = {'prog': self.prog, 'message': message}
# -> 2508         self.exit(2, _('%(prog)s: error: %(message)s\n') % args)
#
# ~/.local/share/ov/pkg/isaac_sim-2022.2.1/kit/python/lib/python3.7/argparse.py in exit(self, status, message)
#    2494             self._print_message(message, _sys.stderr)
# -> 2495         _sys.exit(status)
#    2496
#
# SystemExit: 2
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2091                            'the full traceback.\n']
#    2092                     stb.extend(self.InteractiveTB.get_exception_only(etype,
# -> 2093                                                                      value))
#    2094                 else:
#    2095                     try:
#
# ~/.local/lib/python3.7/site-packages/IPython/core/ultratb.py in get_exception_only(self, etype, value)
#     752         value : exception value
#     753         """
# --> 754         return ListTB.structured_traceback(self, etype, value)
#     755
#     756     def show_exception_only(self, etype, evalue):
#
# ~/.local/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     631                     chained_exceptions_tb_offset, context)
#     632                 + chained_exception_message
# --> 633                 + out_list)
#     634
#     635         return out_list
#
# ~/.local/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1366             self.tb = tb
#    1367         return FormattedTB.structured_traceback(
# -> 1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#    1370
#
# ~/.local/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1266             # Verbose modes need a full traceback
#    1267             return VerboseTB.structured_traceback(
# -> 1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#    1270         elif mode == 'Minimal':
#
# ~/.local/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1123
#    1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1125                                                                tb_offset)
#    1126
#    1127         colors = self.Colors  # just a shorthand + quicker name lookup
#
# ~/.local/lib/python3.7/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/.local/lib/python3.7/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
config_name = "/cfg/train/MFP2D_PPOmulti_dict_MLP.yaml"

with open(config_name, 'r') as stream:
    cfg = yaml.safe_load(stream)

obs_space = spaces.Dict({"state":spaces.Box(np.ones(10) * -np.Inf, np.ones(10) * np.Inf),
                         "transforms":spaces.Box(low=-1, high=1, shape=(8, 5)),
                         "masks":spaces.Box(low=0, high=1, shape=(8,))})

act_space = spaces.Tuple([spaces.Discrete(2)]*8)

player = BasicPpoPlayerDiscrete(cfg, obs_space, act_space, clip_actions=False, deterministic=True)
model_path = "../corl_runs/MLP_GTXY_UF_0.25_ST_PE_0.01_PAV_1.0_PLV_0.01/nn/last_MLP_GTXY_UF_0.25_ST_PE_0.01_PAV_1.0_PLV_0.01_ep_2000_rew_589.91455.pth"
player.restore(model_path)

obs = dict({'state':torch.zeros((1,10), dtype=torch.float32, device='cuda'),
            'transforms': torch.zeros(5,8, device='cuda'),
            'masks': torch.zeros(8, dtype=torch.float32, device='cuda')})

action = player.get_action(obs, is_deterministic=True)

print(action)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_16288/4058950993.py in <module>
#       1 config_name = "cfg/train/MFP2D_PPOmulti_dict_MLP.yaml"
#       2
# ----> 3 with open(config_name, 'r') as stream:
#       4     cfg = yaml.safe_load(stream)
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cfg/train/MFP2D_PPOmulti_dict_MLP.yaml'
