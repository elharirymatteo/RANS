# %% [markdown]
# # Evaluate trained models in different environments and analize results

# %% [markdown]
# Load the necessary library

# %%
import numpy as np
import os

import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

# %% [markdown]
# ### Exp Rew with Uneven Floor 0.25

# %%
res_multi_expR_UF = pd.read_csv("../evaluations/icra24/expR_UF/multi_model_performance.csv", index_col=[0])
res_multi_expR_UF = res_multi_expR_UF.sort_values('avg_ang_vel')
res_multi_expR_UF
# Out:
#                                        model  success_rate_0.02_m  \
# 4  nominal_UF_0.25_GoToXY_MLP_expRew_PE_0.04                100.0
# 3          nominal_UF_0.25_GoToXY_MLP_expRew                100.0
# 0  nominal_UF_0.25_GoToXY_MLP_expRew_PE_0.03                100.0
# 1  nominal_UF_0.25_GoToXY_MLP_expRew_PE_0.01                100.0
# 2  nominal_UF_0.25_GoToXY_MLP_expRew_PE_0.02                100.0
# 5  nominal_UF_0.25_GoToXY_MLP_expRew_PE_0.05                100.0
#
#    success_rate_0.01_m  success_and_stay_within_0.15_m   avg_rew  avg_ang_vel  \
# 4                100.0                      100.000000  0.865813    -4.351103
# 3                100.0                      100.000000  0.849794    -4.311330
# 0                100.0                      100.000000  0.868573    -2.421867
# 1                100.0                       98.437500  0.856268    -1.220997
# 2                100.0                       99.609375  0.875384    -0.001698
# 5                100.0                       96.456693  0.840660     0.009413
#
#    avg_action_count
# 4          43.82725
# 3         101.99575
# 0          54.11275
# 1          91.28450
# 2          69.00325
# 5          20.00400

# %% [markdown]
# ### Exp Rew with Action (and Velocity) Noise

# %%
res_multi_gotoXY_noise = pd.read_csv("../evaluations/icra24_noise/multi_model_performance.csv", index_col=[0])
res_multi_gotoXY_noise = res_multi_gotoXY_noise.sort_values('avg_ang_vel')
res_multi_gotoXY_noise
# Out:
#                                             model  success_rate_0.02_m  \
# 15           nominal_UF_0.25_AN_GoToXY_MLP_expRew                100.0
# 12           nominal_AN_GoToXY_MLP_expRew_PE_0.01                100.0
# 3            nominal_AN_GoToXY_MLP_expRew_PE_0.03                100.0
# 10           nominal_AN_GoToXY_MLP_expRew_PE_0.05                100.0
# 2            nominal_AN_GoToXY_MLP_expRew_PE_0.04                100.0
# 0            nominal_AN_GoToXY_MLP_expRew_PE_0.02                100.0
# 16  nominal_UF_0.25_AVN_GoToXY_MLP_expRew_PE_0.02                100.0
# 9    nominal_UF_0.25_AN_GoToXY_MLP_expRew_PE_0.03                100.0
# 13   nominal_UF_0.25_AN_GoToXY_MLP_expRew_PE_0.04                100.0
# 5    nominal_UF_0.25_AN_GoToXY_MLP_expRew_PE_0.02                100.0
# 4   nominal_UF_0.25_AVN_GoToXY_MLP_expRew_PE_0.01                100.0
# 14  nominal_UF_0.25_AVN_GoToXY_MLP_expRew_PE_0.04                100.0
# 17  nominal_UF_0.25_AVN_GoToXY_MLP_expRew_PE_0.05                100.0
# 7    nominal_UF_0.25_AN_GoToXY_MLP_expRew_PE_0.05                100.0
# 11  nominal_UF_0.25_AVN_GoToXY_MLP_expRew_PE_0.03                100.0
# 8           nominal_UF_0.25_AVN_GoToXY_MLP_expRew                100.0
# 1                    nominal_AN_GoToXY_MLP_expRew                100.0
# 6    nominal_UF_0.25_AN_GoToXY_MLP_expRew_PE_0.01                100.0
#
#     success_rate_0.01_m  success_and_stay_within_0.15_m   avg_rew  \
# 15                100.0                       97.656250  0.860116
# 12                100.0                       99.609375  0.857596
# 3                 100.0                       97.656250  0.857496
# 10                100.0                       98.828125  0.840529
# 2                 100.0                       98.437500  0.853055
# 0                 100.0                       99.218750  0.849914
# 16                100.0                       99.609375  0.870858
# 9                 100.0                       98.828125  0.866972
# 13                100.0                       98.046875  0.859925
# 5                 100.0                       99.609375  0.854995
# 4                 100.0                       99.609375  0.867551
# 14                100.0                       98.828125  0.864896
# 17                100.0                      100.000000  0.866488
# 7                 100.0                      100.000000  0.864270
# 11                100.0                       99.609375  0.868420
# 8                 100.0                       97.656250  0.858288
# 1                 100.0                       98.046875  0.849105
# 6                 100.0                      100.000000  0.858951
#
#     avg_ang_vel  avg_lin_vel  avg_action_count
# 15     0.098934     0.247285         148.81600
# 12     0.130810     0.275420         111.47875
# 3      0.135978     0.223676          42.22200
# 10     0.177695     0.279292          29.43325
# 2      0.179640     0.266853          41.13875
# 0      0.200305     0.247014          55.29275
# 16     0.202100     0.258040          56.66325
# 9      0.209141     0.259848          51.56900
# 13     0.389875     0.297922          21.89875
# 5      0.483322     0.310044          35.04375
# 4      0.915637     0.394348          78.00250
# 14     2.127209     0.552030          39.30975
# 17     2.755104     0.617844          28.49025
# 7      2.986845     0.670917          36.40150
# 11     2.992512     0.678286          51.59125
# 8      3.203328     0.687838         105.46900
# 1      3.321982     0.733567         138.55725
# 6      3.737978     0.772439          88.83350

# %%
sns.heatmap(res_multi_expR.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(res_multi_expR_UF.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## New GoToPose

# %%
res_multi_gotoPose = pd.read_csv("../evaluations/icra24_Pose_lstm/multi_model_performance.csv", index_col=[0])
res_multi_gotoPose_uf = pd.read_csv("../evaluations/icra24_Pose_lstm/multi_model_performance_uf.csv", index_col=[0])

# %% [markdown]
# ### GoToPose

# %%
res_multi_gotoPose = res_multi_gotoPose.sort_values('success_rate_0.02_m', ascending=False)
res_multi_gotoPose
# Out:
#                                  model  success_rate_0.02_m  \
# 5  nominal_GoToPose_MLP_expRew_PE_0.03            46.484375
# 3  nominal_GoToPose_MLP_expRew_PE_0.04            23.046875
# 4  nominal_GoToPose_MLP_expRew_PE_0.05            19.921875
# 2  nominal_GoToPose_MLP_expRew_PE_0.02             7.812500
# 1          nominal_GoToPose_MLP_expRew             3.125000
# 0  nominal_GoToPose_MLP_expRew_PE_0.01             1.171875
#
#    success_rate_0.01_m  success_and_stay_within_0.15_m  \
# 5            24.218750                       43.750000
# 3            11.328125                       21.484375
# 4             8.593750                       16.796875
# 2             3.515625                        6.250000
# 1             1.171875                        1.953125
# 0             0.781250                        0.000000
#
#    success_rate_0.087_rad  success_rate_0.0435_rad  \
# 5                   100.0                    100.0
# 3                   100.0                    100.0
# 4                   100.0                    100.0
# 2                   100.0                    100.0
# 1                   100.0                    100.0
# 0                   100.0                    100.0
#
#    success_and_stay_within_0.6525_rad   avg_rew  avg_ang_vel  avg_lin_vel  \
# 5                           96.875000  1.566300     0.122629     0.559557
# 3                           86.328125  1.461703     0.136862     0.681328
# 4                           93.359375  1.413694     0.156322     0.658119
# 2                           87.890625  1.308423     0.111284     0.580539
# 1                           80.859375  1.187232     0.096728     0.702640
# 0                           73.437500  0.916332     0.122955     0.952667
#
#    avg_action_count
# 5          90.03975
# 3          80.82425
# 4          52.96175
# 2         112.61525
# 1         142.27100
# 0         114.64525

# %% [markdown]
# ### GoToPose with uneven floor

# %%
res_multi_gotoPose_uf = res_multi_gotoPose_uf.sort_values('success_rate_0.02_m', ascending=False)
res_multi_gotoPose_uf
# Out:
#                                          model  success_rate_0.02_m  \
# 2  nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.01           100.000000
# 3          nominal_UF_0.25_GoToPose_MLP_expRew           100.000000
# 5  nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.02           100.000000
# 1  nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.03            99.609375
# 0  nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.05            97.265625
# 4  nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.04            91.796875
#
#    success_rate_0.01_m  success_and_stay_within_0.15_m  \
# 2            98.437500                       98.828125
# 3            94.921875                       98.437500
# 5            89.843750                       99.218750
# 1            96.875000                       99.218750
# 0            73.437500                       94.140625
# 4            78.906250                       91.796875
#
#    success_rate_0.087_rad  success_rate_0.0435_rad  \
# 2                   100.0                    100.0
# 3                   100.0                    100.0
# 5                   100.0                    100.0
# 1                   100.0                    100.0
# 0                   100.0                    100.0
# 4                   100.0                    100.0
#
#    success_and_stay_within_0.6525_rad   avg_rew  avg_ang_vel  avg_lin_vel  \
# 2                           96.484375  1.735016     0.103200     0.542062
# 3                           91.015625  1.726923     0.097854     0.546212
# 5                           91.406250  1.718570     0.115650     0.530148
# 1                           95.312500  1.724653     0.123638     0.535578
# 0                           94.921875  1.624948     0.143178     0.565027
# 4                           91.796875  1.617746     0.149739     0.555763
#
#    avg_action_count
# 2         117.52650
# 3         129.23875
# 5         103.38300
# 1          91.52050
# 0          40.42525
# 4          47.40825

# %%
sns.heatmap(res_multi_gotoPose.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # New grand Matrix

# %% [markdown]
# ## TASK : GoToXY
# ### Nominal environment

# %%
nominal_xy = pd.read_csv("../evaluations/icra24/nominal_xy.csv", index_col=[0])
nominal_xy = nominal_xy.sort_values('avg_rew', ascending=False)
nominal_xy
# Out:
#                                         model  success_rate_0.02_m  \
# 4   nominal_UF_0.25_GoToXY_MLP_expRew_PE_0.02           100.000000
# 2   nominal_UF_0.25_GoToXY_MLP_expRew_PE_0.03           100.000000
# 22       nominal_GoToXY_MLP_r1_expRew_PE_0.02           100.000000
# 8        nominal_GoToXY_MLP_r1_expRew_PE_0.03           100.000000
# 19  nominal_UF_0.25_GoToXY_MLP_expRew_PE_0.04           100.000000
# 26       nominal_GoToXY_MLP_r1_expRew_PE_0.04           100.000000
# 24  nominal_UF_0.25_GoToXY_MLP_expRew_PE_0.05           100.000000
# 10       nominal_GoToXY_MLP_r1_expRew_PE_0.05           100.000000
# 5        nominal_GoToXY_MLP_r2_expRew_PE_0.01           100.000000
# 3   nominal_UF_0.25_GoToXY_MLP_expRew_PE_0.01           100.000000
# 14       nominal_GoToXY_MLP_r1_expRew_PE_0.01           100.000000
# 23       nominal_GoToXY_MLP_r2_expRew_PE_0.02           100.000000
# 20          nominal_GoToXY_MLP_expRew_PE_0.03            98.046875
# 16               nominal_GoToXY_MLP_r1_expRew           100.000000
# 13          nominal_UF_0.25_GoToXY_MLP_expRew            99.609375
# 21          nominal_GoToXY_MLP_expRew_PE_0.04            99.218750
# 1                nominal_GoToXY_MLP_r2_expRew            94.140625
# 17          nominal_GoToXY_MLP_expRew_PE_0.05            99.609375
# 0           nominal_GoToXY_MLP_expRew_PE_0.02            98.437500
# 25          nominal_GoToXY_MLP_linRew_PE_0.01            96.484375
# 12                  nominal_GoToXY_MLP_expRew            78.906250
# 9           nominal_GoToXY_MLP_linRew_PE_0.02            85.546875
# 15          nominal_GoToXY_MLP_expRew_PE_0.01            85.937500
# 11          nominal_GoToXY_MLP_linRew_PE_0.03            86.718750
# 6           nominal_GoToXY_MLP_linRew_PE_0.04            75.390625
# 7           nominal_GoToXY_MLP_linRew_PE_0.05            21.875000
# 18                  nominal_GoToXY_MLP_linRew            10.546875
#
#     success_rate_0.01_m  success_and_stay_within_0.15_m   avg_rew  \
# 4            100.000000                       98.828125  0.806388
# 2            100.000000                       99.218750  0.805857
# 22           100.000000                       98.046875  0.802651
# 8            100.000000                       99.218750  0.801848
# 19           100.000000                       97.265625  0.801251
# 26           100.000000                       97.656250  0.801142
# 24           100.000000                       98.046875  0.796889
# 10            99.609375                       98.046875  0.795861
# 5             99.609375                       98.828125  0.791625
# 3            100.000000                       99.218750  0.791344
# 14           100.000000                       98.437500  0.782328
# 23           100.000000                       99.609375  0.777079
# 20            88.281250                       97.656250  0.768039
# 16            99.609375                       99.218750  0.756645
# 13            99.609375                       98.828125  0.752176
# 21            99.218750                       98.437500  0.747787
# 1             90.625000                       91.015625  0.726549
# 17            97.265625                       98.046875  0.724463
# 0             75.781250                       97.656250  0.706378
# 25            72.265625                       96.093750  0.695612
# 12            47.265625                       78.125000  0.674716
# 9             55.468750                       83.984375  0.670992
# 15            47.265625                       85.156250  0.649379
# 11            57.421875                       85.546875  0.639820
# 6             46.484375                       72.656250  0.559061
# 7              7.421875                       21.484375  0.525689
# 18             5.859375                        3.125000  0.465369
#
#     avg_ang_vel  avg_lin_vel  avg_action_count
# 4      0.165015     0.396913          72.96650
# 2      2.468072     0.611746          59.03775
# 22     0.164738     0.246308          73.42500
# 8      2.465092     0.575159          59.39250
# 19     4.287203     0.867351          50.17725
# 26     4.322810     0.898081          50.15525
# 24     0.166527     0.274487          33.45200
# 10     0.167844     0.288783          33.98325
# 5      0.172797     0.275387         104.10800
# 3      1.291848     0.489447          91.24575
# 14     1.302065     0.426863          91.07375
# 23     3.906552     0.845306          71.77900
# 20     0.175990     0.268241          50.91525
# 16     4.283608     0.806831         102.75250
# 13     4.290205     0.918714         102.76175
# 21     2.370641     0.574565          53.16500
# 1      6.419426     1.449179         108.50625
# 17     5.089351     0.949416          39.01650
# 0      0.423777     0.305214          56.11725
# 25     3.335378     0.732572          71.69125
# 12     1.910582     0.587696         121.41650
# 9      3.316021     0.690092          40.96100
# 15     3.884521     0.862355          97.92000
# 11     5.214139     0.993031          39.24625
# 6      4.918122     1.122907          32.16050
# 7      5.707953     1.140897          23.69925
# 18     1.790949     0.467645         117.92375

# %%
df = nominal_xy

# %% [markdown]
# # Aggregate Score to rank models performance
#
# The aggregate score is calculated as a weighted sum of various performance metrics. Each metric is given a weight (w_i) that reflects its relative importance in assessing the performance of Reinforcement Learning (RL) agents trained for the "go to position" task in a 2D plane.

# %%
def get_aggregate_score_df(df):
    """
    Calculate the aggregate score for each model and return a dataframe with the aggregate scores
    """
    # Define weights as a dictionary
    weights = {
        'success_rate_0.02_m': 20,
        'success_rate_0.01_m': 10,
        'success_and_stay_within_0.15_m': 20,
        'avg_rew': 5,
        'avg_ang_vel': -20,
        'avg_action_count': -10
    }

    # Calculate the aggregate score using dictionary weights
    df['Aggregate_Score'] = sum(weights[key] * df[key] for key in weights.keys())

    # Normalize the aggregate score to a range of 0 to 100
    max_score = df['Aggregate_Score'].max()
    min_score = df['Aggregate_Score'].min()
    df['Normalized_Score'] = 100 * (df['Aggregate_Score'] - min_score) / (max_score - min_score)

    # Display the dataframe with the aggregate scores
    return df[['model', 'Aggregate_Score', 'Normalized_Score']].sort_values('Normalized_Score', ascending=False)

# %% [markdown]
# ## Load all the results in a structured way

# %%
# Loading all the evaluation results

model_folders = ['icra24', 'icra24_noise', 'icra24_Pose', 'icra24_Pose_new', 'icra24_fail']
eval_environments = ['nominal_xy', 'an_xy', 'avn_xy', 'uf_xy', 'uf_an_xy', 'uf_avn_xy']

# create a nested dictionary for the model folders
model_folders_dict = {folder: {env: [] for env in eval_environments} for folder in model_folders}
# Nominal models
for _, folder in enumerate(tqdm(model_folders)):
    for env in eval_environments:
        df = pd.read_csv("../evaluations/"+folder+"/"+env+".csv", index_col=[0])
        if (folder is 'icra24_fail') or (folder is 'icra24_Pose'):
            # merge the df with and without BB
            df_BB = pd.read_csv("../evaluations/"+folder+"/"+env+"_BB.csv", index_col=[0])
            df = pd.concat([df, df_BB])
            print(f'total number of episodes in merged df for folder {folder}: {len(df)}')
        model_folders_dict[folder][env].append(df)
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 98.51it/s]
# total number of episodes in merged df for folder icra24_Pose: 12
# total number of episodes in merged df for folder icra24_Pose: 12
# total number of episodes in merged df for folder icra24_Pose: 12
# total number of episodes in merged df for folder icra24_Pose: 12
# total number of episodes in merged df for folder icra24_Pose: 12
# total number of episodes in merged df for folder icra24_Pose: 12
# total number of episodes in merged df for folder icra24_fail: 24
# total number of episodes in merged df for folder icra24_fail: 24
# total number of episodes in merged df for folder icra24_fail: 24
# total number of episodes in merged df for folder icra24_fail: 24
# total number of episodes in merged df for folder icra24_fail: 24
# total number of episodes in merged df for folder icra24_fail: 24

# %% [markdown]
# ### Showing an working example of how to use the nested dictionary (retrieving by model and env)

# %%
model_folders_dict['icra24_Pose']['nominal_xy'][0]
# Out:
#                                             model  success_rate_0.02_m  \
# 0     nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.05            18.359375
# 1     nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.03             6.250000
# 2     nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.01            12.890625
# 3             nominal_UF_0.25_GoToPose_MLP_expRew             2.343750
# 4     nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.04            40.625000
# 5     nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.02            37.890625
# 0  nominal_UF_0.25_GoToPose_BB_MLP_expRew_PE_0.05             6.250000
# 1  nominal_UF_0.25_GoToPose_BB_MLP_expRew_PE_0.02             9.375000
# 2  nominal_UF_0.25_GoToPose_BB_MLP_expRew_PE_0.03            42.968750
# 3  nominal_UF_0.25_GoToPose_BB_MLP_expRew_PE_0.01            10.156250
# 4  nominal_UF_0.25_GoToPose_BB_MLP_expRew_PE_0.04             5.078125
# 5          nominal_UF_0.25_GoToPose_BB_MLP_expRew             5.859375
#
#    success_rate_0.01_m  success_and_stay_within_0.15_m   avg_rew  avg_ang_vel  \
# 0            10.156250                        1.171875  0.225379     0.131797
# 1             2.343750                        0.390625  0.104391     0.127969
# 2             7.031250                        0.390625  0.145893     0.127475
# 3             1.171875                        0.000000  0.079992     0.136332
# 4            19.921875                        3.125000  0.249933     0.125172
# 5            27.734375                       14.843750  0.377287     0.137814
# 0             1.171875                        0.000000  0.196181     0.136928
# 1             4.296875                        0.000000  0.146046     0.128848
# 2            24.609375                        2.734375  0.172238     0.153256
# 3             3.125000                        0.390625  0.092500     0.132562
# 4             1.562500                        0.000000  0.105254     0.135754
# 5             1.953125                        0.000000  0.089344     0.128847
#
#    avg_lin_vel  avg_action_count
# 0     0.333682          69.92175
# 1     0.616781          89.31925
# 2     0.651614          78.45950
# 3     0.415276          71.89025
# 4     0.431042         100.97475
# 5     0.309810          50.41500
# 0     0.396827          46.11450
# 1     0.594988          69.17350
# 2     0.769592          52.52825
# 3     0.675216          63.77550
# 4     0.498086          45.22775
# 5     0.523312          74.78000

# %%
model_folders_dict['icra24_fail']['nominal_xy'][0]
# Out:
#                                               model  success_rate_0.02_m  \
# 0          fail_1_UF_0.25_GoToXY_MLP_expRew_PE_0.02            98.828125
# 1          fail_1_UF_0.25_GoToXY_MLP_expRew_PE_0.04           100.000000
# 2          fail_1_UF_0.25_GoToXY_MLP_expRew_PE_0.03           100.000000
# 3          fail_1_UF_0.25_GoToXY_MLP_expRew_PE_0.05            97.265625
# 4          fail_1_UF_0.25_GoToXY_MLP_expRew_PE_0.01           100.000000
# 5                  fail_1_UF_0.25_GoToXY_MLP_expRew           100.000000
# 0   fail_1_UF_0.25_AVN_GoToXY_BB_MLP_expRew_PE_0.01            99.218750
# 1               fail_1_UF_0.25_GoToXY_BB_MLP_expRew           100.000000
# 2       fail_1_UF_0.25_GoToXY_BB_MLP_expRew_PE_0.05           100.000000
# 3       fail_1_UF_0.25_GoToXY_BB_MLP_expRew_PE_0.03           100.000000
# 4       fail_1_UF_0.25_GoToXY_BB_MLP_expRew_PE_0.02           100.000000
# 5           fail_1_UF_0.25_AVN_GoToXY_BB_MLP_expRew           100.000000
# 6            fail_1_UF_0.25_AN_GoToXY_BB_MLP_expRew           100.000000
# 7   fail_1_UF_0.25_AVN_GoToXY_BB_MLP_expRew_PE_0.05           100.000000
# 8       fail_1_UF_0.25_GoToXY_BB_MLP_expRew_PE_0.04            99.609375
# 9   fail_1_UF_0.25_AVN_GoToXY_BB_MLP_expRew_PE_0.04           100.000000
# 10      fail_1_UF_0.25_GoToXY_BB_MLP_expRew_PE_0.01           100.000000
# 11   fail_1_UF_0.25_AN_GoToXY_BB_MLP_expRew_PE_0.02           100.000000
# 12  fail_1_UF_0.25_AVN_GoToXY_BB_MLP_expRew_PE_0.02           100.000000
# 13   fail_1_UF_0.25_AN_GoToXY_BB_MLP_expRew_PE_0.04           100.000000
# 14  fail_1_UF_0.25_AVN_GoToXY_BB_MLP_expRew_PE_0.03           100.000000
# 15   fail_1_UF_0.25_AN_GoToXY_BB_MLP_expRew_PE_0.03           100.000000
# 16   fail_1_UF_0.25_AN_GoToXY_BB_MLP_expRew_PE_0.05           100.000000
# 17   fail_1_UF_0.25_AN_GoToXY_BB_MLP_expRew_PE_0.01           100.000000
#
#     success_rate_0.01_m  success_and_stay_within_0.15_m   avg_rew  \
# 0             98.828125                       98.437500  0.777780
# 1            100.000000                       98.828125  0.807147
# 2            100.000000                       99.218750  0.809168
# 3             94.921875                       82.421875  0.737783
# 4             99.609375                       98.828125  0.768955
# 5             96.484375                       99.609375  0.788991
# 0             98.828125                       85.156250  0.767807
# 1            100.000000                       99.218750  0.820154
# 2            100.000000                      100.000000  0.833541
# 3            100.000000                       99.218750  0.832273
# 4            100.000000                       98.437500  0.798100
# 5            100.000000                       98.046875  0.832692
# 6            100.000000                       98.828125  0.816628
# 7            100.000000                       98.437500  0.845564
# 8             99.609375                       96.093750  0.821121
# 9            100.000000                       99.609375  0.837007
# 10           100.000000                      100.000000  0.837450
# 11           100.000000                      100.000000  0.826033
# 12           100.000000                       98.828125  0.839189
# 13           100.000000                      100.000000  0.831947
# 14           100.000000                       99.218750  0.838703
# 15           100.000000                       99.609375  0.834554
# 16           100.000000                       99.218750  0.836920
# 17           100.000000                       98.437500  0.820157
#
#     avg_ang_vel  avg_lin_vel  avg_action_count
# 0      7.194196     1.172650          67.19625
# 1      5.374169     0.970618          50.04100
# 2      3.439392     0.749528          58.32400
# 3      7.305008     1.050897          43.91375
# 4      3.665522     0.815276          96.92750
# 5      2.348678     0.550539         120.24175
# 0      8.114964     1.262556          75.86550
# 1      0.111957     0.252072         125.34700
# 2      0.143850     0.280107          46.19750
# 3      0.167551     0.268652          68.83350
# 4      5.889244     0.974689          55.43950
# 5      0.110279     0.243304         117.34325
# 6      3.287086     0.750815         118.30975
# 7      2.611847     0.608591          35.28150
# 8      6.867939     1.166095          39.91850
# 9      0.153969     0.286770          50.12075
# 10     0.145812     0.254730          89.10775
# 11     0.152323     0.263182          75.65450
# 12     0.145979     0.294943          78.55975
# 13     0.156550     0.269628          51.78550
# 14     0.167617     0.260596          64.14450
# 15     0.156993     0.252969          61.70625
# 16     3.138634     0.667851          37.46025
# 17     3.540951     0.758378          93.69100

# %% [markdown]
# ### Showing how to use the get_aggregate_score_df function to see the Score of single models within the same group

# %%
res_Pose_new = get_aggregate_score_df(model_folders_dict['icra24_Pose_new']['nominal_xy'][0])
res_Pose_new
# Out:
#                                           model  Aggregate_Score  \
# 1   nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.03      -146.562146
# 5           nominal_UF_0.25_GoToPose_MLP_expRew      -288.265178
# 4   nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.01      -339.960553
# 2           nominal_GoToPose_MLP_expRew_PE_0.01      -375.335817
# 11          nominal_GoToPose_MLP_expRew_PE_0.03      -439.716687
# 6           nominal_GoToPose_MLP_expRew_PE_0.02      -490.137438
# 7           nominal_GoToPose_MLP_expRew_PE_0.04      -560.522791
# 10  nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.02      -563.462582
# 9           nominal_GoToPose_MLP_expRew_PE_0.05      -891.622512
# 3                   nominal_GoToPose_MLP_expRew      -960.584532
# 0   nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.05     -1012.178361
# 8   nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.04     -1220.875089
#
#     Normalized_Score
# 1         100.000000
# 5          86.809892
# 4          81.997945
# 2          78.705118
# 11         72.712370
# 6          68.019068
# 7          61.467406
# 10         61.193762
# 9          30.647734
# 3          24.228560
# 0          19.426065
# 8           0.000000

# %%
res_Pose_new = get_aggregate_score_df(model_folders_dict['icra24_fail']['uf_xy'][0])
res_Pose_new
# Out:
#                                               model  Aggregate_Score  \
# 7   fail_1_UF_0.25_AVN_GoToXY_BB_MLP_expRew_PE_0.05      4591.488063
# 16   fail_1_UF_0.25_AN_GoToXY_BB_MLP_expRew_PE_0.05      4573.771644
# 2       fail_1_UF_0.25_GoToXY_BB_MLP_expRew_PE_0.05      4560.481564
# 9   fail_1_UF_0.25_AVN_GoToXY_BB_MLP_expRew_PE_0.04      4520.576789
# 13   fail_1_UF_0.25_AN_GoToXY_BB_MLP_expRew_PE_0.04      4503.527589
# 8       fail_1_UF_0.25_GoToXY_BB_MLP_expRew_PE_0.04      4462.687646
# 1          fail_1_UF_0.25_GoToXY_MLP_expRew_PE_0.04      4391.983499
# 15   fail_1_UF_0.25_AN_GoToXY_BB_MLP_expRew_PE_0.03      4387.656659
# 14  fail_1_UF_0.25_AVN_GoToXY_BB_MLP_expRew_PE_0.03      4369.976983
# 2          fail_1_UF_0.25_GoToXY_MLP_expRew_PE_0.03      4338.299182
# 3       fail_1_UF_0.25_GoToXY_BB_MLP_expRew_PE_0.03      4330.714505
# 4       fail_1_UF_0.25_GoToXY_BB_MLP_expRew_PE_0.02      4318.443015
# 11   fail_1_UF_0.25_AN_GoToXY_BB_MLP_expRew_PE_0.02      4258.178671
# 12  fail_1_UF_0.25_AVN_GoToXY_BB_MLP_expRew_PE_0.02      4225.432430
# 0          fail_1_UF_0.25_GoToXY_MLP_expRew_PE_0.02      4177.024198
# 10      fail_1_UF_0.25_GoToXY_BB_MLP_expRew_PE_0.01      4102.277955
# 4          fail_1_UF_0.25_GoToXY_MLP_expRew_PE_0.01      3962.813001
# 17   fail_1_UF_0.25_AN_GoToXY_BB_MLP_expRew_PE_0.01      3955.187741
# 0   fail_1_UF_0.25_AVN_GoToXY_BB_MLP_expRew_PE_0.01      3937.448124
# 3          fail_1_UF_0.25_GoToXY_MLP_expRew_PE_0.05      3917.102329
# 5           fail_1_UF_0.25_AVN_GoToXY_BB_MLP_expRew      3781.380200
# 5                  fail_1_UF_0.25_GoToXY_MLP_expRew      3739.649988
# 1               fail_1_UF_0.25_GoToXY_BB_MLP_expRew      3729.131740
# 6            fail_1_UF_0.25_AN_GoToXY_BB_MLP_expRew      3705.405181
#
#     Normalized_Score
# 7         100.000000
# 16         98.000591
# 2          96.500722
# 9          91.997219
# 13         90.073110
# 8          85.464067
# 1          77.484661
# 15         76.996350
# 14         75.001088
# 2          71.426050
# 3          70.570072
# 4          69.185157
# 11         62.383949
# 12         58.688330
# 0          53.225158
# 10         44.789577
# 4          29.050084
# 17         28.189526
# 0          26.187499
# 3          23.891348
# 5           8.574256
# 5           3.864741
# 1           2.677691
# 6           0.000000

# %%
res_nominal = get_aggregate_score_df(model_folders_dict['icra24']['nominal_xy'][0])
print(res_nominal['model'])
# Out:
# 24    nominal_UF_0.25_GoToXY_MLP_expRew_PE_0.05
# 10         nominal_GoToXY_MLP_r1_expRew_PE_0.05
# 17            nominal_GoToXY_MLP_expRew_PE_0.05
# 21            nominal_GoToXY_MLP_expRew_PE_0.04
# 26         nominal_GoToXY_MLP_r1_expRew_PE_0.04
# 19    nominal_UF_0.25_GoToXY_MLP_expRew_PE_0.04
# 2     nominal_UF_0.25_GoToXY_MLP_expRew_PE_0.03
# 8          nominal_GoToXY_MLP_r1_expRew_PE_0.03
# 20            nominal_GoToXY_MLP_expRew_PE_0.03
# 4     nominal_UF_0.25_GoToXY_MLP_expRew_PE_0.02
# 22         nominal_GoToXY_MLP_r1_expRew_PE_0.02
# 23         nominal_GoToXY_MLP_r2_expRew_PE_0.02
# 0             nominal_GoToXY_MLP_expRew_PE_0.02
# 3     nominal_UF_0.25_GoToXY_MLP_expRew_PE_0.01
# 14         nominal_GoToXY_MLP_r1_expRew_PE_0.01
# 5          nominal_GoToXY_MLP_r2_expRew_PE_0.01
# 16                 nominal_GoToXY_MLP_r1_expRew
# 13            nominal_UF_0.25_GoToXY_MLP_expRew
# 25            nominal_GoToXY_MLP_linRew_PE_0.01
# 11            nominal_GoToXY_MLP_linRew_PE_0.03
# 9             nominal_GoToXY_MLP_linRew_PE_0.02
# 1                  nominal_GoToXY_MLP_r2_expRew
# 6             nominal_GoToXY_MLP_linRew_PE_0.04
# 15            nominal_GoToXY_MLP_expRew_PE_0.01
# 12                    nominal_GoToXY_MLP_expRew
# 7             nominal_GoToXY_MLP_linRew_PE_0.05
# 18                    nominal_GoToXY_MLP_linRew
# Name: model, dtype: object

# %% [markdown]
# # Env-wise ranking
# ## Creating Aggregate Score dataframe with performace Score normalized over all the models per single environment/

# %% [markdown]
# ##

# %%
# Loading all the evaluation results

model_folders = ['icra24', 'icra24_noise', 'icra24_Pose', 'icra24_Pose_new', 'icra24_fail']
eval_environments = ['nominal_xy', 'an_xy', 'avn_xy', 'uf_xy', 'uf_an_xy', 'uf_avn_xy']

weights = {
    'success_rate_0.02_m': 20,
    'success_rate_0.01_m': 10,
    'success_and_stay_within_0.15_m': 20,
    'avg_rew': 5,
    'avg_ang_vel': -20,
    'avg_action_count': -10
}
# Create a dataframe to store the aggregated scores (and normalized scores) for model (column) and environment (row)

aggregated_scores_by_env = pd.DataFrame(index=eval_environments, columns=model_folders)

# iterate over all environments
for env in eval_environments:
    # Initialize the dictionary to store the aggregated scores for each model
    aggregated_scores = {folder: [] for folder in model_folders}
    # iterate over all models
    for _, folder in enumerate(tqdm(model_folders)):
        df = model_folders_dict[folder][env][0]
        # Calculate the aggregate score using dictionary weights
        aggregated_scores[folder] = sum(weights[key] * df[key] for key in weights.keys())
    # Normalize the aggregate score to a range of 0 to 100 over all models
    max_score = max([aggregated_scores[folder].max() for folder in model_folders])
    min_score = min([aggregated_scores[folder].min() for folder in model_folders])
    for folder in model_folders:
        aggregated_scores[folder] = 100 * (aggregated_scores[folder] - min_score) / (max_score - min_score)
    # Store the aggregated scores for each model in the dataframe
    aggregated_scores_by_env.loc[env] = aggregated_scores
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 1098.68it/s]
# 100%|██████████| 5/5 [00:00<00:00, 1122.07it/s]
# 100%|██████████| 5/5 [00:00<00:00, 1146.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 1325.97it/s]
# 100%|██████████| 5/5 [00:00<00:00, 1035.07it/s]
# 100%|██████████| 5/5 [00:00<00:00, 1140.38it/s]

# %% [markdown]
# #### Showing an example of Normalized Score values for a Specific set of models (trained under similar conditions)

# %%
aggregated_scores_by_env['icra24_Pose_new'][0]
# Out:
# 0      3.551592
# 1     18.282611
# 2     14.389350
# 3      4.429613
# 4     14.991365
# 5     15.871115
# 6     12.435661
# 7     11.237847
# 8      0.000000
# 9      5.603206
# 10    11.187817
# 11    13.293720
# dtype: float64

# %%
aggregated_scores_by_env['icra24_fail'][0]
# Out:
# 0     90.918624
# 1     95.191299
# 2     94.573346
# 3     88.192071
# 4     87.724003
# 5     83.940393
# 0     84.741613
# 1     84.300858
# 2     98.026675
# 3     93.900410
# 4     93.963552
# 5     85.265713
# 6     84.284518
# 7     98.513562
# 8     95.276614
# 9     97.222916
# 10    90.723893
# 11    93.010173
# 12    92.120179
# 13    97.071254
# 14    94.698907
# 15    95.250063
# 16    98.228657
# 17    88.255068
# dtype: float64

# %% [markdown]
# ### Creating the daframes to show the Max and Mean values per every set of models (columns) for each specific environment (rows)

# %%
# Create a copy of aggregated_scores_by_env to store only the max scores for each environment and model
max_scores_by_env = aggregated_scores_by_env.copy()
for env in eval_environments:
    max_scores_by_env.loc[env] = max_scores_by_env.loc[env].apply(lambda x: max(x))

# Create a copy of aggregated_scores_by_env to store only the average scores for each environment and model
avg_scores_by_env = aggregated_scores_by_env.copy()
for env in eval_environments:
    avg_scores_by_env.loc[env] = avg_scores_by_env.loc[env].apply(lambda x: np.mean(x))

# %%
# round the values of the max_scores_by_env dataframe to 2 decimal places
for env in eval_environments:
    max_scores_by_env.loc[env] = max_scores_by_env.loc[env].apply(lambda x: round(x, 2))
    avg_scores_by_env.loc[env] = avg_scores_by_env.loc[env].apply(lambda x: round(x, 2))
# Rename columns
max_scores_by_env.columns = ['XY_nominal', 'XY_noise', 'Pose', 'Pose_noise', 'XY_fail_1']
avg_scores_by_env.columns = ['XY_nominal', 'XY_noise', 'Pose', 'Pose_noise', 'XY_fail_1']

# %%
# print max_scores_by_env to a latex table, with small and compact dimensions for the table
print(max_scores_by_env.to_latex(index=True, escape=False, column_format='|l|l|l|l|l|l|', longtable=False,
                                    caption='Maximum scores for each environment and model', label='tab:max_scores_by_env',
                                    bold_rows=True, multicolumn=True, multicolumn_format='|c|', na_rep='-'))
# Out:
# \begin{table}
# \centering
# \caption{Maximum scores for each environment and model}
# \label{tab:max_scores_by_env}
# \begin{tabular}{|l|l|l|l|l|l|}
# \toprule
# {} & XY_nominal & XY_noise &   Pose & Pose_noise & XY_fail_1 \\
# \midrule
# \textbf{nominal_xy} &      99.52 &    100.0 &  34.85 &      18.28 &     98.51 \\
# \textbf{an_xy     } &      100.0 &    99.09 &  30.59 &      20.04 &     98.61 \\
# \textbf{avn_xy    } &      100.0 &    100.0 &  33.65 &      20.79 &     98.79 \\
# \textbf{uf_xy     } &      100.0 &    99.76 &  37.14 &      20.33 &     98.51 \\
# \textbf{uf_an_xy  } &      100.0 &    99.76 &  37.14 &      20.33 &     98.51 \\
# \textbf{uf_avn_xy } &      99.78 &    100.0 &   36.1 &      20.67 &      98.7 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
max_scores_by_env
# Out:
#            XY_nominal XY_noise   Pose Pose_noise XY_fail_1
# nominal_xy      99.52    100.0  34.85      18.28     98.51
# an_xy           100.0    99.09  30.59      20.04     98.61
# avn_xy          100.0    100.0  33.65      20.79     98.79
# uf_xy           100.0    99.76  37.14      20.33     98.51
# uf_an_xy        100.0    99.76  37.14      20.33     98.51
# uf_avn_xy       99.78    100.0   36.1      20.67      98.7

# %%
# concatenate the two dataframes keeping the same number of columns, and add a column to indicate the type of score
scores_by_env = pd.concat([max_scores_by_env, avg_scores_by_env], axis=1)
# create sub-columns for each type of score (max and avg) for each environment, keeping the same index
scores_by_env.columns = pd.MultiIndex.from_product([['max', 'avg'], scores_by_env.columns])
scores_by_env
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_682861/232375488.py in <module>
#       2 scores_by_env = pd.concat([max_scores_by_env, avg_scores_by_env], axis=1)
#       3 # create sub-columns for each type of score (max and avg) for each environment, keeping the same index
# ----> 4 scores_by_env.columns = pd.MultiIndex.from_product([['max', 'avg'], scores_by_env.columns])
#       5 scores_by_env
#
# ~/.local/share/ov/pkg/isaac_sim-2022.2.1/kit/python/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5498         try:
#    5499             object.__getattribute__(self, name)
# -> 5500             return object.__setattr__(self, name, value)
#    5501         except AttributeError:
#    5502             pass
#
# ~/.local/share/ov/pkg/isaac_sim-2022.2.1/kit/python/lib/python3.7/site-packages/pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/.local/share/ov/pkg/isaac_sim-2022.2.1/kit/python/lib/python3.7/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     764     def _set_axis(self, axis: int, labels: Index) -> None:
#     765         labels = ensure_index(labels)
# --> 766         self._mgr.set_axis(axis, labels)
#     767         self._clear_item_cache()
#     768
#
# ~/.local/share/ov/pkg/isaac_sim-2022.2.1/kit/python/lib/python3.7/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     214     def set_axis(self, axis: int, new_labels: Index) -> None:
#     215         # Caller is responsible for ensuring we have an Index object.
# --> 216         self._validate_set_axis(axis, new_labels)
#     217         self.axes[axis] = new_labels
#     218
#
# ~/.local/share/ov/pkg/isaac_sim-2022.2.1/kit/python/lib/python3.7/site-packages/pandas/core/internals/base.py in _validate_set_axis(self, axis, new_labels)
#      56         elif new_len != old_len:
#      57             raise ValueError(
# ---> 58                 f"Length mismatch: Expected axis has {old_len} elements, new "
#      59                 f"values have {new_len} elements"
#      60             )
#
# ValueError: Length mismatch: Expected axis has 10 elements, new values have 20 elements

# %%
avg_scores_by_env
# Out:
#            XY_nominal XY_noise   Pose Pose_noise XY_fail_1
# nominal_xy      82.81    92.36  16.98      10.44     91.89
# an_xy           83.06    92.61  16.37      10.56     91.91
# avn_xy          83.55    93.17  16.75      10.71     92.23
# uf_xy           88.53    93.24  18.38      11.31     91.91
# uf_an_xy        88.53    93.24  18.38      11.31     91.91
# uf_avn_xy       89.04    93.47  18.49      11.54     92.06

# %% [markdown]
# # Go To Pose task
#
# Here we evaluate models for the Pose task

# %% [markdown]
# ### Load the models

# %%
# Loading all the evaluation results

model_folders = ['icra24_Pose_new']
pose_eval_environments = ['nominal_pose', 'an_pose', 'avn_pose', 'uf_pose', 'uf_an_pose', 'uf_avn_pose']

# create a nested dictionary for the model folders
pose_models_dict = {folder: {env: [] for env in pose_eval_environments} for folder in model_folders}
# Nominal models
for _, folder in enumerate(tqdm(model_folders)):
    for env in pose_eval_environments:
        df = pd.read_csv("../evaluations/"+folder+"/"+env+".csv", index_col=[0])
        if (folder is 'icra24_fail') or (folder is 'icra24_Pose'):
            # merge the df with and without BB
            df_BB = pd.read_csv("../evaluations/"+folder+"/"+env+"_BB.csv", index_col=[0])
            df = pd.concat([df, df_BB])
            print(f'total number of episodes in merged df for folder {folder}: {len(df)}')
        pose_models_dict[folder][env].append(df)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 56.19it/s]

# %%
res_Pose_new = get_aggregate_score_df(pose_models_dict['icra24_Pose_new']['nominal_pose'][0])
res_Pose_new
# Out:
#                                           model  Aggregate_Score  \
# 1   nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.03      3769.826057
# 4   nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.01      3684.172817
# 10  nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.02      3640.092084
# 5           nominal_UF_0.25_GoToPose_MLP_expRew      3415.830062
# 0   nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.05      2998.271659
# 8   nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.04      2831.152503
# 11          nominal_GoToPose_MLP_expRew_PE_0.03      1194.971301
# 9           nominal_GoToPose_MLP_expRew_PE_0.05       459.452441
# 7           nominal_GoToPose_MLP_expRew_PE_0.04        55.911030
# 6           nominal_GoToPose_MLP_expRew_PE_0.02      -789.169453
# 2           nominal_GoToPose_MLP_expRew_PE_0.01     -1145.348291
# 3                   nominal_GoToPose_MLP_expRew     -1337.914006
#
#     Normalized_Score
# 1         100.000000
# 4          98.323070
# 10         97.460051
# 5          93.069420
# 0          84.894408
# 8          81.622527
# 11         49.589158
# 9          35.189074
# 7          27.288488
# 6          10.743392
# 2           3.770077
# 3           0.000000

# %%
res_Pose_new = get_aggregate_score_df(pose_models_dict['icra24_Pose_new']['uf_pose'][0])
res_Pose_new
# Out:
#                                           model  Aggregate_Score  \
# 0   nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.05      4163.508686
# 1   nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.03      4036.258016
# 8   nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.04      4001.818295
# 10  nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.02      3875.968314
# 4   nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.01      3823.120695
# 5           nominal_UF_0.25_GoToPose_MLP_expRew      3684.826968
# 11          nominal_GoToPose_MLP_expRew_PE_0.03      2856.045871
# 7           nominal_GoToPose_MLP_expRew_PE_0.04      1454.114540
# 9           nominal_GoToPose_MLP_expRew_PE_0.05      1423.398316
# 6           nominal_GoToPose_MLP_expRew_PE_0.02      -291.789093
# 3                   nominal_GoToPose_MLP_expRew      -888.287673
# 2           nominal_GoToPose_MLP_expRew_PE_0.01     -1144.770867
#
#     Normalized_Score
# 0         100.000000
# 1          97.602789
# 8          96.953996
# 10         94.583172
# 4          93.587602
# 5          90.982357
# 11         75.369368
# 7          48.959091
# 9          48.380443
# 6          16.068893
# 3           4.831757
# 2           0.000000

# %%
res_Pose_new = get_aggregate_score_df(pose_models_dict['icra24_Pose_new']['an_pose'][0])
res_Pose_new
# Out:
#                                           model  Aggregate_Score  \
# 1   nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.03      3703.973519
# 4   nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.01      3689.747406
# 10  nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.02      3476.612499
# 5           nominal_UF_0.25_GoToPose_MLP_expRew      3474.520817
# 0   nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.05      3208.012608
# 8   nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.04      2713.244651
# 11          nominal_GoToPose_MLP_expRew_PE_0.03       965.060280
# 7           nominal_GoToPose_MLP_expRew_PE_0.04       210.607640
# 9           nominal_GoToPose_MLP_expRew_PE_0.05       154.748582
# 6           nominal_GoToPose_MLP_expRew_PE_0.02      -807.621853
# 2           nominal_GoToPose_MLP_expRew_PE_0.01     -1122.029696
# 3                   nominal_GoToPose_MLP_expRew     -1311.367907
#
#     Normalized_Score
# 1         100.000000
# 4          99.716348
# 10         95.466689
# 5          95.424983
# 0          90.111124
# 8          80.246033
# 11         45.389296
# 7          30.346400
# 9          29.232636
# 6          10.044103
# 2           3.775181
# 3           0.000000

# %%
res_Pose_new = get_aggregate_score_df(pose_models_dict['icra24_Pose_new']['avn_pose'][0])
res_Pose_new
# Out:
#                                           model  Aggregate_Score  \
# 1   nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.03      3702.118145
# 4   nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.01      3675.651693
# 10  nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.02      3581.623930
# 5           nominal_UF_0.25_GoToPose_MLP_expRew      3363.931312
# 0   nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.05      3091.953520
# 8   nominal_UF_0.25_GoToPose_MLP_expRew_PE_0.04      2956.475755
# 11          nominal_GoToPose_MLP_expRew_PE_0.03      1065.839718
# 9           nominal_GoToPose_MLP_expRew_PE_0.05       287.404988
# 7           nominal_GoToPose_MLP_expRew_PE_0.04       113.920564
# 6           nominal_GoToPose_MLP_expRew_PE_0.02      -703.760358
# 2           nominal_GoToPose_MLP_expRew_PE_0.01     -1092.517256
# 3                   nominal_GoToPose_MLP_expRew     -1201.723948
#
#     Normalized_Score
# 1         100.000000
# 4          99.460292
# 10         97.542861
# 5          93.103635
# 0          87.557417
# 8          84.794731
# 11         46.240552
# 9          30.366576
# 7          26.828851
# 6          10.154560
# 2           2.226962
# 3           0.000000
